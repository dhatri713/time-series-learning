# %%
import pandas as pd
# %matplotlib inline

# %%
pwd
# Out:
# '/home/dhatri/Time Series'

# %%
cd ..
# Out:
# /home/dhatri

# %%
cd Documents/
# Out:
# /home/dhatri/Documents

# %%
cd UDEMY_TSA_FINAL/
# Out:
# /home/dhatri/Documents/UDEMY_TSA_FINAL

# %%
ls
# Out:
# 00-Intro-to-Time-Series/                   07-Deep-Learning-Models/
# 01-NumPy/                                  08-Prophet-Library/
# 02-Pandas/                                 09-NO-VIDEO-Bonus-Notebooks/
# 03-Pandas-Visualization/                   Data/
# 04-Time-Series-with-Pandas/                Pierian_Data_Logo.png
# 05-Time-Series-Analysis-with-Statsmodels/  tsa_course_env.yml
# 06-General-Forecasting-Models/

# %%
cd  03-Pandas-Visualization/
# Out:
# /home/dhatri/Documents/UDEMY_TSA_FINAL/03-Pandas-Visualization

# %%
ls
# Out:
# '00-Pandas Built-in Data Visualization.ipynb'            df1.csv
#  01-Customizing-Plots.ipynb                              df2.csv
#  02-Pandas-Data-Visualization-Exercise.ipynb             df3.csv
#  03-Pandas-Data-Visualization-Exercise-Solutions.ipynb

# %%
df1 = pd.read_csv('df1.csv', index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2.csv')

# %%
df2
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y
# 5  0.286043  0.593465  0.907307  0.637898  x
# 6  0.430436  0.166230  0.469383  0.497701  z
# 7  0.312296  0.502823  0.806609  0.850519  z
# 8  0.187765  0.997075  0.895955  0.530390  x
# 9  0.908162  0.232726  0.414138  0.432007  y

# %%
df1['A'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot.hist(edgecolor='k')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot.hist(bins=200, edgecolor='k').autoscale(enable=True, axis='both', tight=True)

# %%
df1['A'].plot.hist(grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# pandas uses the idnex by default for bar plots
df2.plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df2.plot.barh()
# Out:
# <Axes: >

# %%
df2.plot.line(y='a', lw=4)
# Out:
# <Axes: >

# %%
df2.plot.line(y=['a', 'b', 'c'], lw=4, alpha=0.4)
# Out:
# <Axes: >

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df1.plot.scatter(x='A', y='B', c='D', cmap='coolwarm')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', c='D', cmap='coolwarm')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df2
# Out:
#           a         b         c         d  e
# 0  0.039762  0.218517  0.103423  0.957904  x
# 1  0.937288  0.041567  0.899125  0.977680  y
# 2  0.780504  0.008948  0.557808  0.797510  x
# 3  0.672717  0.247870  0.264071  0.444358  z
# 4  0.053829  0.520124  0.552264  0.190008  y
# 5  0.286043  0.593465  0.907307  0.637898  x
# 6  0.430436  0.166230  0.469383  0.497701  z
# 7  0.312296  0.502823  0.806609  0.850519  z
# 8  0.187765  0.997075  0.895955  0.530390  x
# 9  0.908162  0.232726  0.414138  0.432007  y

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2['c'].plot.line(figsize=(20, 3), ls='--', c='red', lw=5)
# Out:
# <Axes: >

# %%
title = "MY PLOT TITLE"
xlabel = 'x data'
ylabel = 'y data'

# %%
ax = df2['c'].plot.line(figsize=(20, 3), ls='--', c='red', lw=5, title=title)
ax.set(xlabel=xlabel, ylabel=ylabel)
# Out:
# [Text(0.5, 0, 'x data'), Text(0, 0.5, 'y data')]

# %%
ax.set(title=title)
# Out:
# [Text(0.5, 1.0, 'MY PLOT TITLE')]

# %%
ax
# Out:
# <Axes: title={'center': 'MY PLOT TITLE'}, xlabel='x data', ylabel='y data'>

# %%
ax = df2.plot()
#ax.legend(loc=5)
ax.legend(loc=0, bbox_to_anchor=(1.0, 1.0))
