# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
import statsmodels.api as sm
# just a general convention for calling things off statsmodels

# %%
from statsmodels.tsa.stattools import acovf, acf, pacf, pacf_yw, pacf_ols

# %%
cd ..
# Out:
# /home/dhatri

# %%
cd Documents/UDEMY_TSA_FINAL/Data/
# Out:
# /home/dhatri/Documents/UDEMY_TSA_FINAL/Data

# %%
# non-stationary
df1 = pd.read_csv('airline_passengers.csv', index_col='Month', parse_dates=True)

# %%
df1.index.freq = 'MS'

# %%
df1.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq='MS')

# %%
# stationary
df2 = pd.read_csv('DailyTotalFemaleBirths.csv', index_col='Date', parse_dates=True)
df2.index.freq = 'D'

# %%
df1.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121

# %%
df2.head()
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.DataFrame({'a': [13, 5, 11, 10, 9]})

# %%
df
# Out:
#     a
# 0  13
# 1   5
# 2  11
# 3  10
# 4   9

# %%
acf(df['a'])
# Out:
# array([ 1.        , -0.61818182,  0.05909091,  0.11704545, -0.05795455])

# %%
pacf_yw(df['a'], nlags=4, method='mle')
# Out:
# array([ 1.        , -0.61818182, -0.52287319, -0.33536484, -0.21334515])

# %%
pacf_ols(df['a'], nlags=4)
# Out:
# array([ 1.        , -0.61151079, -0.25      ,  0.31400105,  0.28125   ])

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(df1['Thousands of Passengers'])
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %%
lag_plot(df2['Births'])
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
df1.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
plot_acf(df1, lags=40);

# %%
plot_acf(df2, lags=40);

# %%
plot_pacf(df2, lags=40);
